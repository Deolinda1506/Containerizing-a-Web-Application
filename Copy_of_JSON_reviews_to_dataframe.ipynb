# %% [markdown]
# <a href="https://colab.research.google.com/github/Deolinda1506/Containerizing-a-Web-Application/blob/main/Copy_of_JSON_reviews_to_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd

# %%
file_path = '/content/data_7.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
reviews_data = []
count = 0
for result in data['results']:
  asin = result['content']["asin"]
  for review in result['content']['reviews']:
    count += 1
    try:
      review_info = {
      'review_id': review['id'],
      'product_id': asin,
      "title": review["title"],
      "author": review["author"],
      "rating": review["rating"],
      "content": review["content"],
      "timestamp": review["timestamp"],
      "profile_id": review["profile_id"],
      "is_verified": review["is_verified"],
      "helpful_count": review.get('helpful_count', 0),
      "product_attributes": review["product_attributes"]
      }
      reviews_data.append(review_info)
    except:
      print(count)
      break

reviews_df = pd.DataFrame(reviews_data)
reviews_df.to_csv('reviews_7.csv', index=False)
reviews_df
# Out:
#          review_id  product_id  \
# 0   R158T5SJCSV7IQ  B08X4VXF1M
# 1   R3AK5LLZ1VVTWJ  B08X4VXF1M
# 2    RPPZYO5WBVQNH  B08X4VXF1M
# 3   R3VELE8MJDOXTB  B08X4VXF1M
# 4    RKVC70KJ7EC14  B08X4VXF1M
# ..             ...         ...
# 95  R123AULHTZMUKV  B08X4VXF1M
# 96   RI0ANP2T9LZXW  B08X4VXF1M
# 97  R18VKXRJKPXGGW  B08X4VXF1M
# 98  R1STXNJWKQDI80  B08X4VXF1M
# 99  R1KENNYGKLTKVH  B08X4VXF1M
#
#                                                 title                  author  \
# 0   5.0 out of 5 stars Amazing Sound and Great Dur...            Miguel Gomez
# 1   5.0 out of 5 stars INSANE Speaker! Quality, vo...                  Jeremy
# 2   5.0 out of 5 stars Great portable speaker with...                   Plumb
# 3      5.0 out of 5 stars So far, absolutely amazing.                 TO Scar
# 4                      5.0 out of 5 stars Great Sound         Sunshinegirl502
# ..                                                ...                     ...
# ...

# %%
len(reviews_df)
# Out:
# 100

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# @title Default title text
df_1 = pd.read_csv('/content/reviews.csv')
df_2 = pd.read_csv('/content/reviews_1.csv')
df_3 = pd.read_csv('/content/reviews_2.csv')
df_4 = pd.read_csv('/content/reviews_3.csv')
df_5 = pd.read_csv('/content/reviews_4.csv')
df_6 = pd.read_csv('/content/reviews_5.csv')
df_7 = pd.read_csv('/content/reviews_6.csv')



df_7.head()
# Out:
#         review_id  product_id  \
# 0  R14Y1942I1N3R3  B08FCGLYFZ
# 1  R32T26HS9LWBNS  B08FCGLYFZ
# 2  R353SROP7DA5WX  B08FCGLYFZ
# 3    R9XAFIFZZGGO  B08FCGLYFZ
# 4  R1Q0KU47IE0MTW  B08FCGLYFZ
#
#                                                title               author  \
# 0                 5.0 out of 5 stars Mind your ears!                   ES
# 1              5.0 out of 5 stars Good Sound Quality          Olympusmons
# 2   5.0 out of 5 stars Best headphones I've ever had  Arkten Arachlassair
# 3  5.0 out of 5 stars Literally the best thing I ...         Zane Lawliet
# 4               5.0 out of 5 stars WOW! Just... WOW!               Wes VK
#
#    rating                                            content  \
# 0       5  This headphone is very capable of deafening yo...
# 1       5  Venturing into the world of audio bliss, I emb...
# 2       5  First of all, a bit about me that's relevant. ...
# 3       5  There’s really not much to say. Assuming you a...
# ...

# %%
merged_df.to_csv('merged_data.csv', index=False)

# %%
merged_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7], ignore_index=True)
merged_df
# Out:
#           review_id  product_id  \
# 0     R1UGHCCYN8419  B07R5QD598
# 1     R7FPOTZIXQMHE  B07R5QD598
# 2     RYGNKCJF3Q2P3  B07R5QD598
# 3    R2WMIQOXTJA88Q  B07R5QD598
# 4     RT337LQW55P9W  B07R5QD598
# ..              ...         ...
# 695  R1L3OP062YHDUP  B08FCGLYFZ
# 696  R2DSJR1P6J90Q0  B08FCGLYFZ
# 697  R16H4HUAT9NTDG  B08FCGLYFZ
# 698  R2HV3IQHN8IC07  B08FCGLYFZ
# 699   RCFMKABKK3CH7  B08FCGLYFZ
#
#                                                  title        author  rating  \
# 0        5.0 out of 5 stars Almost perfect headphones.     RowNut405       5
# 1           5.0 out of 5 stars Exceptional Performance  Fadi Shamaan       5
# 2    5.0 out of 5 stars Glad I waited for the Power...       Patrick       5
# 3    5.0 out of 5 stars The best Earphones you will...          Mike       5
# 4    4.0 out of 5 stars Running Earphone Showdown -...           Joe       4
# ..                                                 ...           ...     ...
# ...
